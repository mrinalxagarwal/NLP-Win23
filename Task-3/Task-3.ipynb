# %% [markdown]
# # 13.01.2023 | Hands-On

# %% [markdown]
# # Task 1

# %%
def gender_features(word):
    # Extracrs and returns last character of the word
    return{'last_letter': word[-1]}

# %%
gender_features("Mrinal")
# Out:
# {'last_letter': 'l'}

# %%
from nltk.corpus import names
import random

# %%
# Attaching the label 'male' with every name in the male.txt file, and doing the same with every name in the female.txt file.
labeled_names = ([(name,'male') for name in names.words('male.txt')]+[(name,'female') for name in names.words('female.txt')])

# %%
random.shuffle(labeled_names)
labeled_names
# Out:
# [('Sarita', 'female'),
#  ('Berk', 'male'),
#  ('Dode', 'female'),
#  ('Winfred', 'male'),
#  ('Ameline', 'female'),
#  ('Melody', 'female'),
#  ('Reeba', 'female'),
#  ('Husain', 'male'),
#  ('Bethina', 'female'),
#  ('Marys', 'female'),
#  ('Cyrus', 'male'),
#  ('Lotte', 'female'),
#  ('Eddie', 'female'),
#  ('Fortune', 'female'),
#  ('Theresina', 'female'),
#  ('Lonni', 'female'),
#  ('Nealson', 'male'),
#  ('Constantinos', 'male'),
#  ('Joletta', 'female'),
#  ('Emalee', 'female'),
#  ('Aurelia', 'female'),
#  ('Pooh', 'female'),
#  ('Lizabeth', 'female'),
#  ('Ritch', 'male'),
#  ('Charo', 'female'),
#  ('Elfie', 'female'),
#  ('Kirbee', 'female'),
#  ('Ollie', 'female'),
#  ('Berte', 'female'),
#  ('Ebony', 'female'),
#  ('Buffy', 'female'),
#  ('Herold', 'male'),
#  ('Spiro', 'male'),
#  ('Tobie', 'male'),
#  ('Wallis', 'male'),
#  ('Debbra', 'female'),
#  ('Garfield', 'male'),
#  ('Shaine', 'female'),
#  ('Osmond', 'male'),
#  ('Meira', 'female'),
#  ('Francyne', 'female'),
# ...

# %%
len(labeled_names)
# Out:
# 7944

# %%
featuresets = [(gender_features(n),gender) for (n,gender) in labeled_names]
featuresets
# Out:
# [({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'k'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'd'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'y'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 's'}, 'female'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'i'}, 'female'),
#  ({'last_letter': 'n'}, 'male'),
#  ({'last_letter': 's'}, 'male'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'a'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'h'}, 'female'),
#  ({'last_letter': 'h'}, 'male'),
#  ({'last_letter': 'o'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
#  ({'last_letter': 'e'}, 'female'),
# ...

# %%
len(featuresets)
# Out:
# 7944

# %%
train_set, test_set = featuresets[500:],featuresets[:500]

# %%
import nltk
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('Mrinal'))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.806

# %% [markdown]
# # Task 2 - Tweet Tokenizer!

# %%
import nltk
from nltk.tokenize import TweetTokenizer
text = "The Party was soooo fun :D #superfun💗🤩"
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'Party', 'was', 'soooo', 'fun', ':D', '#superfun', '💗', '🤩']

# %% [markdown]
# # Task 3 - COCA

# %% [markdown]
# 3.1 - Find the frequency count of a word

# %% [markdown]
# ![Task%203-3-1.png](attachment:Task%203-3-1.png)

# %% [markdown]
# 3.2 - Chart - word - frequency; section; sub-section; Year

# %% [markdown]
# ![Task%203-3-2.png](attachment:Task%203-3-2.png)

# %% [markdown]
# Collocate - Display three collocations on the left and right each of the word

# %% [markdown]
# ![Task%203-3-3-1.png](attachment:Task%203-3-3-1.png)

# %% [markdown]
# ![Task%203-3-3-2.png](attachment:Task%203-3-3-2.png)
